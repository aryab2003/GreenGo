# %% [markdown]
# <a href="https://colab.research.google.com/github/aryab2003/GreenGo/blob/main/Flower_Location.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
df= pd.read_csv('plant_123.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                   common_name     family categories  \
# 0           0                 Janet Craig    Liliaceae   Dracaena
# 1           1                   Lady palm    Arecaceae       Palm
# 2           2    Tailflower ,  Wax flower      Araceae  Anthurium
# 3           3                Elephant ear      Araceae      Other
# 4           4          Malaysian Dracaena    Liliaceae   Dracaena
#
#          origin         climate     zone  \
# 0    Cultivar          Tropical  [11,10]
# 1       China       Subtropical  [11, 9]
# 2    Cultivar          Tropical     [11]
# 3      Hybrid    Tropical humid     [11]
# 4    Cultivar          Tropical  [11,10]
#
#                                              img_url
# 0  http://www.tropicopia.com/house-plant/thumbnai...
# 1  http://www.tropicopia.com/house-plant/thumbnai...
# 2  http://www.tropicopia.com/house-plant/thumbnai...
# 3  http://www.tropicopia.com/house-plant/thumbnai...
# ...

# %%
df['origin'].value_counts()
# Out:
# origin
#   Cultivar                              123
#   Hybrid                                 54
#   Mexico                                 22
#   Brazil                                 17
#   Madagascar                             17
#   South Africa                           16
#   Asia                                    9
#   Malaysia                                8
#   China                                   8
#   India                                   8
#   South Pacific                           7
#   Japan                                   6
#   Central America                         5
#   Taiwan                                  5
#   Venezuela                               5
#   Africa                                  4
#   Australia                               4
#   Philippines                             3
#   New Calidonia                           3
#   Canaries                                3
#   Guinea                                  2
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-f874ac6189f6> in <cell line: 1>()
# ----> 1 df.drop('Unnamed: 0',axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
df['Flower']=df['common_name']+' '+df['family']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'common_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.drop(['common_name'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-008aa3f2aef7> in <cell line: 1>()
# ----> 1 df.drop(['common_name'],axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
df.drop(['Image'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-423f4fe97f87> in <cell line: 1>()
# ----> 1 df.drop(['Image'],axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
df.drop(['categories'],axis=1,inplace=True)

# %%
df
# Out:
#            origin         climate     zone  \
# 0      Cultivar          Tropical  [11,10]
# 1         China       Subtropical  [11, 9]
# 2      Cultivar          Tropical     [11]
# 3        Hybrid    Tropical humid     [11]
# 4      Cultivar          Tropical  [11,10]
# ..            ...             ...      ...
# 350      Hybrid          Tropical     [11]
# 351      Hybrid          Tropical     [11]
# 352    Cultivar          Tropical     [12]
# 353    Cultivar          Tropical  [11,10]
# 354      Mexico     Arid Tropical  [10, 8]
#
#                                                img_url  \
# 0    http://www.tropicopia.com/house-plant/thumbnai...
# 1    http://www.tropicopia.com/house-plant/thumbnai...
# 2    http://www.tropicopia.com/house-plant/thumbnai...
# 3    http://www.tropicopia.com/house-plant/thumbnai...
# 4    http://www.tropicopia.com/house-plant/thumbnai...
# ..                                                 ...
# ...

# %%
df.drop(['img_url'],axis=1,inplace=True)

# %%
df
# Out:
#            origin         climate     zone  Flower
# 0      Cultivar          Tropical  [11,10]      59
# 1         China       Subtropical  [11, 9]      65
# 2      Cultivar          Tropical     [11]     110
# 3        Hybrid    Tropical humid     [11]      37
# 4      Cultivar          Tropical  [11,10]      74
# ..            ...             ...      ...     ...
# 350      Hybrid          Tropical     [11]      26
# 351      Hybrid          Tropical     [11]      26
# 352    Cultivar          Tropical     [12]      96
# 353    Cultivar          Tropical  [11,10]      94
# 354      Mexico     Arid Tropical  [10, 8]      14
#
# [353 rows x 4 columns]

# %%
df.describe()
# Out:
#               origin   climate     zone                         Flower
# count            353       355      355                            334
# unique            39         6       18                            133
# top       Cultivar    Tropical  [11,10]    Chinese Evergreen   Araceae
# freq             123       264      204                             37

# %%
df.isnull().sum()
df.dropna(inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Flower']=le.fit_transform(df['Flower'])

# %%
X= df.drop(['Flower'],axis=1)
y= df['Flower']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
model=LogisticRegression()
model.fit(X_train,y_train)
pred=model.predict(X_test)
print(confusion_matrix(y_test,pred))
print(accuracy_score(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-9b85a4041dd4> in <cell line: 2>()
#       1 model=LogisticRegression()
# ----> 2 model.fit(X_train,y_train)
#       3 pred=model.predict(X_test)
#       4 print(confusion_matrix(y_test,pred))
#       5 print(accuracy_score(y_test,pred))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
# Load the dataset
df = pd.read_csv('plant_123.csv')

# Clean the dataset
df.drop('Unnamed: 0', axis=1, inplace=True)
df['Flower'] = df['common_name'] + ' ' + df['family']
df.drop(['common_name', 'categories', 'img_url'], axis=1, inplace=True)

# Check for and drop missing values
df.dropna(inplace=True)

# Identify categorical features
categorical_features = ['origin', 'climate', 'zone']  # Adjust this list based on your actual categorical columns

# One-hot encode the categorical variables
encoder = OneHotEncoder(sparse=False)
encoded_features = encoder.fit_transform(df[categorical_features])
encoded_feature_names = encoder.get_feature_names_out(categorical_features)

# Create a DataFrame from the encoded features and concatenate it with the original DataFrame
encoded_df = pd.DataFrame(encoded_features, columns=encoded_feature_names)
df = df.drop(columns=categorical_features).reset_index(drop=True)
df = pd.concat([df, encoded_df], axis=1)

# Split features and target variable
X = df.drop(['Flower', 'family'], axis=1)  # Drop 'family' if it is non-numeric
y = df['Flower']


# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Train a Logistic Regression model
model = RandomForestClassifier(n_estimators=200,max_depth=)
model.fit(X_train, y_train)

model1=GradientBoostingClassifier()
model1.fit(X_train,y_train)

# Make predictions
pred = model.predict(X_test)
pred1=model1.predict(X_test)


# Evaluate the model

print(accuracy_score(y_test, pred))
print(accuracy_score(y_test,pred1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.417910447761194
# 0.43283582089552236

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
# Load the dataset
df = pd.read_csv('plant_123.csv')

# Clean the dataset
df.drop('Unnamed: 0', axis=1, inplace=True)
df['Flower'] = df['common_name'] + ' ' + df['family']
df.drop(['common_name', 'categories', 'img_url'], axis=1, inplace=True)

# Check for and drop missing values
df.dropna(inplace=True)

# Identify categorical features
categorical_features = ['origin', 'climate', 'zone']  # Adjust this list based on your actual categorical columns

# One-hot encode the categorical variables
encoder = OneHotEncoder(sparse=False)
encoded_features = encoder.fit_transform(df[categorical_features])
encoded_feature_names = encoder.get_feature_names_out(categorical_features)

# Create a DataFrame from the encoded features and concatenate it with the original DataFrame
encoded_df = pd.DataFrame(encoded_features, columns=encoded_feature_names)
df = df.drop(columns=categorical_features).reset_index(drop=True)
df = pd.concat([df, encoded_df], axis=1)

# Split features and target variable
X = df.drop(['Flower', 'family'], axis=1)  # Drop 'family' if it is non-numeric
y = df['Flower']
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0                             Janet Craig   Liliaceae
# 1                               Lady palm   Arecaceae
# 2                  Tailflower ,  Wax flower   Araceae
# 3                              Elephant ear   Araceae
# 4                      Malaysian Dracaena   Liliaceae
#                             ...
# 327                       Chinese Evergreen   Araceae
# 328                       Chinese Evergreen   Araceae
# 329                     Silver Calathea   Marantaceae
# 330                           Rubber plant   Moraceae
# 331      Blue Agave ,  Century plant   Amaryllidaceae
# Name: Flower, Length: 332, dtype: object

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.neighbors import LocalOutlierFactor

# Load the dataset
df = pd.read_csv('plant_123.csv')

# Clean the dataset
df.drop('Unnamed: 0', axis=1, inplace=True)
df['Flower'] = df['common_name'] + ' ' + df['family']
df.drop(['common_name', 'categories', 'img_url'], axis=1, inplace=True)

# Convert 'zone' lists to strings
df['zone'] = df['zone'].apply(lambda x: ','.join(map(str, eval(x))) if isinstance(x, str) else x)

# Check for and drop missing values
df.dropna(inplace=True)

# Identify categorical and numeric features
categorical_features = ['origin', 'climate', 'zone']  # Adjust this list based on your actual categorical columns
numeric_features = [col for col in df.columns if col not in categorical_features + ['Flower', 'family']]

# Split features and target variable
X = df.drop(['Flower', 'family'], axis=1)  # Drop 'family' if it is non-numeric
y = df['Flower']

# Encode categorical features for outlier detection
X_encoded = pd.get_dummies(X, columns=categorical_features)

# Detect and remove outliers using Local Outlier Factor
lof = LocalOutlierFactor()
outliers = lof.fit_predict(X_encoded)
mask = outliers != -1
X, y = X[mask], y[mask]

# Define the column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Initialize models
models = {
    'RandomForestClassifier': RandomForestClassifier(n_estimators=100, random_state=0),
    'GradientBoostingClassifier': GradientBoostingClassifier(n_estimators=100, random_state=0),
    'XGBClassifier': XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=0)
}

# Function to create pipeline and evaluate model
def evaluate_model(model, X_train, X_test, y_train, y_test):
    pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    print(f"Model: {model.__class__.__name__}")
    print(confusion_matrix(y_test, y_pred))
    print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
    print(classification_report(y_test, y_pred))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Evaluate each model
for name, model in models.items():
    evaluate_model(model, X_train, X_test, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-5b3639ab121a> in <cell line: 72>()
#      71 # Evaluate each model
#      72 for name, model in models.items():
# ---> 73     evaluate_model(model, X_train, X_test, y_train, y_test)
#
# <ipython-input-55-5b3639ab121a> in evaluate_model(model, X_train, X_test, y_train, y_test)
#      60     pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])
#      61     pipeline.fit(X_train, y_train)
# ---> 62     y_pred = pipeline.predict(X_test)
#      63     print(f"Model: {model.__class__.__name__}")
#      64     print(confusion_matrix(y_test, y_pred))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in predict(self, X, **predict_params)
#     478         Xt = X
#     479         for _, name, transform in self._iter(with_final=False):
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
data = pd.read_csv('plant_123.csv')
# Handle missing values (if any)
data.dropna(inplace=True)

# Encode categorical features
categorical_features = ['family', 'categories', 'origin', 'climate', 'zone']
encoder = OneHotEncoder()
encoded_features = encoder.fit_transform(data[categorical_features])

# Prepare the target variable
target = data['common_name']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(encoded_features, target, test_size=0.2, random_state=42)

# Train a Decision Tree model
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
accuracy

import joblib

joblib.dump(model, 'plant_classifier_model.pkl')
# Out:
# ['plant_classifier_model.pkl']

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
data = pd.read_csv('plant_123.csv')
# Handle missing values (if any)
data.dropna(inplace=True)

# Encode categorical features
categorical_features = ['family', 'categories', 'origin', 'climate', 'zone']
encoder = OneHotEncoder()
encoded_features = encoder.fit_transform(data[categorical_features])

# Prepare the target variable
target = data['common_name']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(encoded_features, target, test_size=0.2, random_state=42)
# Define the parameter grid for the Random Forest model
# param_grid = {
#     'n_estimators': [50, 100, 200],
#     'max_depth': [None, 10, 20, 30],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4],
#     'bootstrap': [True, False]
# }

# # Initialize the Random Forest model
# rf = RandomForestClassifier(random_state=42)

# # Initialize GridSearchCV
# grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

# # Fit GridSearchCV
# grid_search.fit(X_train, y_train)

# # Print the best parameters
# print(f"Best parameters: {grid_search.best_params_}")

# # Predict using the best model
# best_rf = grid_search.best_estimator_
# y_pred_rf_best = best_rf.predict(X_test)

# # Calculate accuracy
# accuracy_rf_best = accuracy_score(y_test, y_pred_rf_best)
# print(f"Random Forest Accuracy after tuning: {accuracy_rf_best}")
pruned_dt = DecisionTreeClassifier(random_state=42)
pruned_dt.fit(X_train, y_train)

# Make predictions
y_pred_pruned = pruned_dt.predict(X_test)

# Evaluate the model
accuracy_pruned = accuracy_score(y_test, y_pred_pruned)
print(f"Accuracy with pruning: {accuracy_pruned}")
# Out:
# Accuracy with pruning: 0.5223880597014925

# %%
from sklearn.ensemble import BaggingClassifier

# Initialize the Bagging Classifier with Decision Tree
bagging = BaggingClassifier(base_estimator=DecisionTreeClassifier(random_state=42),
                            n_estimators=100,  # Number of trees
                            random_state=42)

# Fit the Bagging Classifier
bagging.fit(X_train, y_train)

# Make predictions
y_pred_bagging = bagging.predict(X_test)

# Evaluate the model
accuracy_bagging = accuracy_score(y_test, y_pred_bagging)
print(f"Accuracy with Bagging: {accuracy_bagging}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Accuracy with Bagging: 0.5522388059701493
